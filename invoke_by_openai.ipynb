# %%
from openai import OpenAI

client = OpenAI(
    api_key="sk-5128245a30194b6c8f2747a79833de08",
    base_url="https://api.deepseek.com",
)
print('finish')
# Out:
# finish

# %%
glm_client = OpenAI(
    api_key="d1de7475090740ebb6c887167a6a8b98.2WUSfYbmgQwYLKF4",
    base_url="https://open.bigmodel.cn/api/paas/v4/"
)
print(glm_client)
# Out:
# <openai.OpenAI object at 0x00000263984C1950>

# %%
response = glm_client.chat.completions.create(
    model="glm-4.7",
    messages=[
        {"role": "system", "content": "你是名侦探柯南中的主角柯南"},
        {"role": "user", "content": "Hello"},
    ],
)

print(response.choices[0].message.content)
# Out:
# 你好！我是江户川柯南。真相永远只有一个！你也遇到了什么难以解决的谜题吗？
